# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
url = 'http://www.yahoo.co.jp/'

# %%
ua = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) '\
     'AppleWebKit/537.36 (KHTML, like Gecko) '\
     'Chrome/55.0.2883.95 Safari/537.36 '

# %%
req = urllib.request.Request(url, headers={'User-Agent': ua})
html = urllib.request.urlopen(req)
soup = BeautifulSoup(html, "html.parser")
topicsindex = soup.find('div', attrs={'class': 'topicsindex'})
topics = topicsindex.find_all('li')

# %%
for topic in topics:
    print(topic.find('a').contents[0])
# Out:
# 徴用工 日本企業70社にリスク
# 東京医大 学費1千万円減検討
# 川重 鉄道事業「撤退も検討」
# 墜落LCC「飛行制御に問題」
# 車体にマット塗装増 実は大変
# 島根を鳥取に 地図誤植が話題
# SBが乱打戦制す 1勝1敗1分に
# RIP SLYME公式サイト 閉鎖へ
# もっと見る
# トピックス一覧

# %%
mikuurl = 'https://www5.atwiki.jp/hmiku/pages/22012.html'

# %%
req = urllib.request.Request(mikuurl, headers={'User-Agent': ua})
html = urllib.request.urlopen(req)
soup = BeautifulSoup(html, "lxml")
wikibody = soup.find('div', attrs={'id': 'wikibody'})
body = wikibody.find_all('div')

# %%
body
# Out:
# [<div style="text-align:right"><!--@@@@@--><div>
#  【登録タグ:<a href="/hmiku/tag/CHUNITHM">CHUNITHM</a> <a href="/hmiku/tag/O">O</a> <a href="/hmiku/tag/ryo">ryo</a> <a href="/hmiku/tag/%E5%88%9D%E9%9F%B3%E3%83%9F%E3%82%AF">初音ミク</a> <a href="/hmiku/tag/%E5%88%9D%E9%9F%B3%E3%83%9F%E3%82%AF-ProjectDIVA-f">初音ミク-ProjectDIVA-f</a> <a href="/hmiku/tag/%E6%9B%B2">曲</a>】
#  </div>
#  </div>, <div>
#  【登録タグ:<a href="/hmiku/tag/CHUNITHM">CHUNITHM</a> <a href="/hmiku/tag/O">O</a> <a href="/hmiku/tag/ryo">ryo</a> <a href="/hmiku/tag/%E5%88%9D%E9%9F%B3%E3%83%9F%E3%82%AF">初音ミク</a> <a href="/hmiku/tag/%E5%88%9D%E9%9F%B3%E3%83%9F%E3%82%AF-ProjectDIVA-f">初音ミク-ProjectDIVA-f</a> <a href="/hmiku/tag/%E6%9B%B2">曲</a>】
# ...

# %%
for text in wikibody.find_all(text=True):
    if text.strip():
        print(text)
# Out:
# ODDS&ENDS
# @@@@@
# @@@@@
#
# 【登録タグ:
# CHUNITHM
# O
# ryo
# 初音ミク
# 初音ミク-ProjectDIVA-f
# 曲
# 】
#
# 0-0
#
# (function($){
# $(function(){
# $(window).load(function(){
# $(".plugin_youtube img").each(function(){
# if ( this.width > 100 ){$(this).next().css("display","inline-block");
# } });
# });
# $(document).on('click', '.plugin_youtube a', function(e){
# cancelEvent(e);
# $(this).parent().html('<iframe src="https://www.youtube.com/embed/'+$(this).data('code')+'autoplay=1&wmode=transparent" frameborder="0" width="'+$(this).data('width')+'" height="'+$(this).data('height')+'" allowfullscreen ></iframe>');
# });
# function cancelEvent(e){
# if ( e.preventDefault) {
# e.preventDefault();
# } else if (window.event) {
# window.event.returnValue = false;
# }};
# });
# })( atwiki_j$ );
#
# 0-1
#
# 作詞：
# ryo
#
# 作曲：
# ryo
#
# 編曲：
# ryo
#
# 唄：初音ミク
#
#
# 曲紹介
# @@@@@
# ODDS&ENDS。
# @@@@@
# がらくた。半端もの。
# @@@@@
# これはミクと、そして僕の話。
# 本作Project Diva fのオープニングテーマ曲でもあるryo氏の書きおろし楽曲
# ...
