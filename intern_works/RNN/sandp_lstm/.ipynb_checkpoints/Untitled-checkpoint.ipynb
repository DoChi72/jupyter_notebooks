# %%
import lstm

# %%
import time
import matplotlib.pyplot as plt

# %%
def plot_results_multiple(predicted_data, true_data, prediction_len):
    fig = plt.figure(facecolor = 'white')
    ax = fig.add_subplot(111)
    ax.plot(true_data, label ='True Data')
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label = 'Prediction')
        plt.legend()
    plt.show()

# %%
epoch = 1
seq_len = 50

# %%
X_train, y_train, X_test, y_test = lstm.load_data('sp500.csv', seq_len, True)

# %%
model = lstm.build_model([1, 50, 100, 1])
# Out:
#  実行時間：　 0.02625894546508789

# %%
model.fit(X_train, y_train, batch_size=512, nb_epoch=epoch, validation_split=0.05)
# Out:
# Train on 3523 samples, validate on 186 samples
# Epoch 1/1
# 3523/3523 [==============================] - 5s 1ms/step - loss: 0.0025 - val_loss: 6.6591e-04

# %%
predictions = lstm.predict_sequences_multiple(model, X_test, seq_len, 50)

# %%
plot_results_multiple(predictions, y_test, 50)
