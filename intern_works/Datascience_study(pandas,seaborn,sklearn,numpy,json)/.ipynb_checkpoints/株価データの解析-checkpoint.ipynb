# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
pd.core.common.is_list_like = pd.api.types.is_list_like
from pandas_datareader.data import DataReader

# %%
from datetime import datetime

# %%
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# %%
end = datetime.now()

# %%
start = datetime(end.year - 1, end.month, end.day)

# %%
for stock in tech_list:
    globals()[stock] = DataReader(stock, 'robinhood', start, end)

# %%
AAPL.describe()
# Out:
#              volume
# count  2.520000e+02
# mean   3.003075e+07
# std    1.290892e+07
# min    1.251979e+07
# 25%    2.116271e+07
# 50%    2.660712e+07
# 75%    3.531207e+07
# max    9.624675e+07

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 252 entries, (AAPL, 2017-10-04 00:00:00) to (AAPL, 2018-10-03 00:00:00)
# Data columns (total 7 columns):
# close_price     252 non-null object
# high_price      252 non-null object
# interpolated    252 non-null bool
# low_price       252 non-null object
# open_price      252 non-null object
# session         252 non-null object
# volume          252 non-null int64
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.9+ KB

# %%
AAPL
# Out:
#                   close_price  high_price  interpolated   low_price  \
# symbol begins_at
# AAPL   2017-10-04  151.193900  151.568300         False  150.189100
#        2017-10-05  153.075500  153.124700         False  151.755400
#        2017-10-06  152.986800  153.174000         False  152.257800
#        2017-10-09  153.518800  154.395500         False  153.169100
#        2017-10-10  153.577900  155.646600         False  152.789800
#        2017-10-11  154.218200  154.641800         False  153.430100
#        2017-10-12  153.676400  155.026000         False  153.410300
#        2017-10-13  154.651700  154.937300         False  154.080300
#        2017-10-16  157.498600  157.616800         False  155.301800
#        2017-10-17  158.079800  158.473900         False  156.858300
#        2017-10-18  157.380400  158.316200         False  157.222800
#        2017-10-19  153.656700  154.740300         False  152.711000
# ...

# %%
AAPL['close_price'] = AAPL['close_price'].astype('float')

AAPL['close_price'].plot(legend=True, figsize=(10,4))

# %%
AAPL['volume'].plot(legend=True, figsize=(10,4))

# %%
ma_day = [10,20,50]
for ma in ma_day:
    column_name = 'MA {}'.format(ma)
    #AAPL[column_name] = pd.rolling_mean(AAPL['close_price'], ma)
    AAPL[column_name] = AAPL['close_price'].rolling(ma).mean()

# %%
AAPL
# Out:
#                    close_price  high_price  interpolated   low_price  \
# symbol begins_at
# AAPL   2017-10-04     151.1939  151.568300         False  150.189100
#        2017-10-05     153.0755  153.124700         False  151.755400
#        2017-10-06     152.9868  153.174000         False  152.257800
#        2017-10-09     153.5188  154.395500         False  153.169100
#        2017-10-10     153.5779  155.646600         False  152.789800
#        2017-10-11     154.2182  154.641800         False  153.430100
#        2017-10-12     153.6764  155.026000         False  153.410300
#        2017-10-13     154.6517  154.937300         False  154.080300
#        2017-10-16     157.4986  157.616800         False  155.301800
#        2017-10-17     158.0798  158.473900         False  156.858300
#        2017-10-18     157.3804  158.316200         False  157.222800
#        2017-10-19     153.6567  154.740300         False  152.711000
# ...

# %%
AAPL[[('close_price'), 'MA 10', 'MA 20', 'MA 50']].plot(subplots=False, figsize=(10,4))

# %%
AAPL['Daily Return'] = AAPL['close_price'].pct_change()

# %%
AAPL['Daily Return'].plot(figsize=(10,4), legend=True, linestyle='--', marker='o')

# %%
sns.distplot(AAPL['Daily Return'].dropna(), bins=100, color='purple')
# Out:
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
AAPL['Daily Return'].hist(bins=100)

# %%
closing_df = DataReader(['AAPL', 'GOOG', 'MSFT', 'AMZN'],
                        'robinhood',
                        start,
                        end)
closing_df = closing_df['close_price'].unstack().T
closing_df['AAPL'] = closing_df['AAPL'].astype('float')
closing_df['GOOG'] = closing_df['GOOG'].astype('float')
closing_df['MSFT'] = closing_df['MSFT'].astype('float')
closing_df['AMZN'] = closing_df['AMZN'].astype('float')

# %%
closing_df.head()
# Out:
# symbol          AAPL    AMZN    GOOG     MSFT
# begins_at
# 2017-10-04  151.1939  965.45  951.68  73.3612
# 2017-10-05  153.0755  980.85  969.96  74.6184
# 2017-10-06  152.9868  989.58  978.89  74.6479
# 2017-10-09  153.5188  990.99  977.00  74.9327
# 2017-10-10  153.5779  987.20  972.60  74.9327

# %%
tech_rets = closing_df.pct_change()

# %%
tech_rets.head()
# Out:
# symbol          AAPL      AMZN      GOOG      MSFT
# begins_at
# 2017-10-04       NaN       NaN       NaN       NaN
# 2017-10-05  0.012445  0.015951  0.019208  0.017137
# 2017-10-06 -0.000579  0.008900  0.009207  0.000395
# 2017-10-09  0.003477  0.001425 -0.001931  0.003815
# 2017-10-10  0.000385 -0.003824 -0.004504  0.000000

# %%
sns.jointplot('GOOG', 'GOOG', tech_rets, kind='scatter', color='seagreen')
# Out:
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot('GOOG', 'MSFT', tech_rets, kind='scatter', color='seagreen')
# Out:
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(tech_rets.dropna())

# %%
returns_fig = sns.PairGrid(tech_rets.dropna())
returns_fig.map_upper(plt.scatter)
returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
returns_fig.map_diag(plt.hist, bins=30)
# Out:
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...

# %%
returns_fig = sns.PairGrid(closing_df.dropna())
returns_fig.map_upper(plt.scatter, color='purple')
returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
returns_fig.map_diag(plt.hist, bins=30)
# Out:
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...

# %%
sns.heatmap(tech_rets.corr(), annot=True)

# %%
rets = tech_rets.dropna()

# %%
rets.head()
# Out:
# symbol          AAPL      AMZN      GOOG      MSFT
# begins_at
# 2017-10-05  0.012445  0.015951  0.019208  0.017137
# 2017-10-06 -0.000579  0.008900  0.009207  0.000395
# 2017-10-09  0.003477  0.001425 -0.001931  0.003815
# 2017-10-10  0.000385 -0.003824 -0.004504  0.000000
# 2017-10-11  0.004169  0.007901  0.017119  0.001704

# %%
plt.scatter(rets.mean(), rets.std(), alpha=0.5, s = np.pi*20)
plt.ylim([0.01, 0.02])
plt.xlim([-0.005,0.01])

plt.xlabel('Expected returns')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x,y), xytext=(0,50),
                textcoords = 'offset points', ha = 'right', va='bottom',
                arrowprops = dict(arrowstyle='-', connectionstyle= 'arc3'))

# %%
sns.distplot(AAPL['Daily Return'].dropna(),bins=100,color='purple')
# Out:
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
rets['AAPL'].quantile([0.05])
# Out:
# 0.05   -0.021075
# Name: AAPL, dtype: float64

# %%
days = 365
dt = 1/days
mu = rets.mean()['GOOG']
sigma = rets.std()['GOOG']

# %%
def stock_monte_carlo(start_price, days, mu, sigma):
    price = np.zeros(days)
    price[0] = start_price
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1, days):
        shock[x] = np.random.normal(loc=mu*dt, scale=sigma*np.sqrt(dt))
        drift[x] = mu * dt
        price[x] = price[x-1] + (price[x-1]*(drift[x]+shock[x]))
    return price

# %%
GOOG.head()
# Out:
#                   close_price  high_price  interpolated   low_price  \
# symbol begins_at
# GOOG   2017-10-04  951.680000  960.390000         False  950.690000
#        2017-10-05  969.960000  970.910000         False  955.180000
#        2017-10-06  978.890000  979.460000         False  963.360000
#        2017-10-09  977.000000  985.425000         False  976.110000
#        2017-10-10  972.600000  981.570000         False  966.080100
#
#                    open_price session   volume
# symbol begins_at
# GOOG   2017-10-04  957.000000     reg   952391
#        2017-10-05  955.490000     reg  1213816
#        2017-10-06  966.700000     reg  1173882
#        2017-10-09  980.000000     reg   891355
#        2017-10-10  980.000000     reg   968362

# %%
start_price = float(GOOG.iloc[0,0])

for run in range(5):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis')
# Out:
# Text(0.5,1,'Monte Carlo Analysis')

# %%
runs = 10000
simulations = np.zeros(runs)
np.set_printoptions(threshold=5)
for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price, days, mu, sigma)[days-1]

# %%
plt.hist(simulations, bins=200)
# Out:
# (array([1., 0., 0., ..., 0., 0., 1.]),
#  array([ 896.04725192,  896.60174889,  897.15624585, ..., 1005.83765155,
#         1006.39214852, 1006.94664549]),
#  <a list of 200 Patch objects>)

# %%
q = np.percentile(simulations, 1)
plt.hist(simulations, bins=200)

plt.figtext(0.6, 0.8, s='Start price: {:0.2f}'.format(start_price))
plt.figtext(0.6, 0.7, 'mean final price: {:0.2f}'.format(simulations.mean()))
plt.figtext(0.6, 0.6, 'VaR(0.99): {:0.2f}'.format(start_price-q))
plt.figtext(0.15, 0.6, 'q(0.99): {:0.2f}'.format(q))

plt.axvline(x=q, linewidth=3, color='r')
