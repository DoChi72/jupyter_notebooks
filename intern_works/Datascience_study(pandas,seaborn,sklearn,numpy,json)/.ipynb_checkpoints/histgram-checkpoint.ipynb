# %%
from numpy.random import randn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 7., 11., 10., 22., 18., 13.,  9.,  5.,  3.,  2.]),
#  array([-1.85543645, -1.41222526, -0.96901407, -0.52580287, -0.08259168,
#          0.36061951,  0.8038307 ,  1.24704189,  1.69025309,  2.13346428,
#          2.57667547]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 5.,  7., 14., 19., 17., 11.,  3.,  3.,  0.,  1.]),
#  array([-2.20546739, -1.63857611, -1.07168484, -0.50479356,  0.06209771,
#          0.62898899,  1.19588027,  1.76277154,  2.32966282,  2.89655409,
#          3.46344537]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, density=True)
# Out:
# (array([0.15793825, 0.24818868, 0.22562607, 0.49637736, 0.40612693,
#         0.29331389, 0.20306346, 0.11281304, 0.06768782, 0.04512521]),
#  array([-1.85543645, -1.41222526, -0.96901407, -0.52580287, -0.08259168,
#          0.36061951,  0.8038307 ,  1.24704189,  1.69025309,  2.13346428,
#          2.57667547]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, density=True, alpha=0.5, bins=20)
plt.hist(dataset2, density=True, alpha=0.5, bins=20, color='indianred')
# Out:
# (array([0.08820033, 0.1323005 , 0.08820033, 0.22050084, 0.264601  ,
#         0.35280134, 0.52920201, 0.30870117, 0.52920201, 0.22050084,
#         0.264601  , 0.22050084, 0.04410017, 0.08820033, 0.1323005 ,
#         0.        , 0.        , 0.        , 0.        , 0.04410017]),
#  array([-2.20546739, -1.92202175, -1.63857611, -1.35513047, -1.07168484,
#         -0.7882392 , -0.50479356, -0.22134792,  0.06209771,  0.34554335,
#          0.62898899,  0.91243463,  1.19588027,  1.4793259 ,  1.76277154,
#          2.04621718,  2.32966282,  2.61310846,  2.89655409,  3.17999973,
#          3.46344537]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)
# Out:
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(data1,data2, kind='hex')
# Out:
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/yamaguchishota/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
