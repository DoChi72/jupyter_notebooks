# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="pHash.css">
# Out:
# <link rel="stylesheet" type="text/css" href="pHash.css">

# %% [markdown]
# * 自己紹介
# * 研究の経歴
# * redfoxインターンシップでの成果
# * cyzenの改善
# * redfoxがこれからすべきこと

# %% [markdown]
# # 自己紹介
# ## <b>山口翔太</b> <br/>

# %% [markdown]
# 1992/9/26<br/>
# 北海道小樽市生まれアフリカタンザニア育ち東京在住
#
# * 都立小山台高校 卒業
#
# * 東海大学 工学部 航空宇宙学科 航空宇宙学専攻 卒業
#
# * 東海大学大学院 工学研究科 機械工学専攻

# %% [markdown]
# ## 趣味
# ロードバイク、野球、SF、テレビゲーム、アーケードゲーム、音楽ライブ、競馬、etc.

# %% [markdown]
# # 研究の経歴
# * 超高速衝突実験
# * 通信のための画像変換技術

# %% [markdown]
# 研究１
# # 超高速衝突実験
# * 超高速衝突（数km/s）による電磁波放射が確認されている
#  * 電磁波放射のメカニズムは未解明
#  * 超高速衝突に伴う現象との関連について未解明

# %% [markdown]
# 研究２
# # 通信のための画像変換技術
# * 画像の類似性を確かめる知覚ハッシュの技術を用いる
#  * 画像は波の集合で表すことが可能（フーリエ変換、離散コサイン変換）
#  * 波の選択方法でオリジナルの手法を作る

# %% [markdown]
# # 離散コサイン変換の基底画像の例
# <img src= 離散コサイン変換基底画像.png height="200">

# %% [markdown]
# # 離散コサイン変換の解説
# ![%E9%9B%A2%E6%95%A3%E3%82%B3%E3%82%B5%E3%82%A4%E3%83%B3%E5%A4%89%E6%8F%9B.jpg](attachment:%E9%9B%A2%E6%95%A3%E3%82%B3%E3%82%B5%E3%82%A4%E3%83%B3%E5%A4%89%E6%8F%9B.jpg)

# %% [markdown]
# # redfoxインターンシップでの成果
# * cyzenの試用期間データの視覚化
# * 報告書テキストのセンチメントアナリシス（ネガ-ポジスコア）
# * 報告書テキストのクラスタリング

# %% [markdown]
# <b>インターンシップで取り扱ったデータからは有効な顧客の傾向が見られなかった</b>

# %% [markdown]
# # cyzenの試用期間データの視覚化
# ![%E5%8F%AF%E8%A6%96%E5%8C%96.png](attachment:%E5%8F%AF%E8%A6%96%E5%8C%96.png)

# %% [markdown]
# # 報告書テキストのセンチメントアナリシス（ネガ-ポジスコア）
# 「時は内乱の最中である。秘密基地を発った反乱軍の宇宙船団が、邪悪な銀河帝国軍に対して初の勝利を収めた。この戦いで、反乱軍のスパイは帝国軍の究極兵器の設計図を奪取することに成功する。それはデス・スターと呼ばれる、惑星をも完全に破壊できる力を持った巨大宇宙ステーションだった。設計図を受け取ったレイア姫は、人々を救い、銀河系に平和を取り戻すべく、自船で故郷へと向かうが
# 帝国軍の密使に発見されてしまったのだった・・・」
# ⬇︎

# %% [markdown]
# {'時': -0.753339, '内乱': -0.424156, '最中': -0.518285, '邪悪': -0.998351, '初': -0.470901, '勝利': 0.640964, '収める': -0.855641, '戦い': -0.767698, 'スパイ': -0.355393, '成功': -0.387167, '呼ぶ': -0.931867, '惑星': -0.463749, '完全': -0.317574, '破壊': -0.454169, '力': -0.84291, '救う': 0.989773, '銀河系': -0.199152, '平和': 0.170938, '故郷': -0.508876, '向かう': -0.74591, '密使': -0.259138, '発見': -0.309154}

# %% [markdown]
# # 報告書テキストのクラスタリング![%E3%82%AF%E3%83%A9%E3%82%B9%E3%82%BF%E3%83%AA%E3%83%B3%E3%82%AF%E3%82%99.png](attachment:%E3%82%AF%E3%83%A9%E3%82%B9%E3%82%BF%E3%83%AA%E3%83%B3%E3%82%AF%E3%82%99.png)

# %% [markdown]
# # cyzenの改善
# <b>取得するデータをデータ解析用に設計するべき</b>

# %% [markdown]
# 顧客からの要望と社員の返答や処理内容、選択的な回答が混在しており、それらを分別できていない。<br/>
# いつの時点で解約したかわからないため、何が原因で解約したか判別できない

# %% [markdown]
# # cyzenの改善
# <b>情報共有機能の強化</b>

# %% [markdown]
# タスクをスレッド形式にして管理<br/>
# メーラー機能と連携して読んで欲しいトピックや社内報を受信

# %% [markdown]
# # redfoxがこれからすべきこと

# %% [markdown]
# * テクノロジーがこれからどのような楽を与えるか

# %% [markdown]
# <b>それは社会の在り方で変わってしまう</b><br/>
# であるならば...

# %% [markdown]
# <b>企業や事業レベルでプロジェクト立ち上げ、社会そのものを変化させその時流に乗る</b>
