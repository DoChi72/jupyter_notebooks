# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="pHash.css">
# Out:
# <link rel="stylesheet" type="text/css" href="pHash.css">

# %% [markdown]
# * data_scienceフォルダはデータの統計的な処理と視覚化を行ったコード
# * Datascience_studyフォルダはインターンシップを始めた時に必要なライブラリ等を学習した時のもの
# * RNN_machinelerningフォルダは機械学習の導入を学んだ時のコード
# * sentiment_analysisフォルダはテキストマイニングを行った時のコード

# %% [markdown]
# # 株式会社レッドフォックス、インターンシップでの成果
# * cyzenの試用期間データの視覚化
# * 報告書テキストのセンチメントアナリシス（ネガ-ポジスコア）
# * 報告書テキストのクラスタリング

# %% [markdown]
# 上記を期間中に勉強し、実際にアプリケーションの履歴データを統計的に扱い、視覚化を行い社内報で閲覧して頂いた。
# 実際のものは社外秘の顧客データを含んでしまうため、以下のものは持ち出させて頂いた一部のコードを実行結果を模したものである。

# %% [markdown]
# # cyzenの試用期間データの視覚化
# ![./data/視覚化.png](attachment:%E5%8F%AF%E8%A6%96%E5%8C%96.png)

# %% [markdown]
# データの視覚化をした例。
# アプリケーションの一部の利用データを、現在の株式会社レッドフォックスで提示されている利用プランを契約か未契約かで分類したものである。
# この例のように、他にもデータの視覚化を行い、回帰分析やデータの時系列の推移見るなどをし、分析を行った。

# %% [markdown]
# # 報告書テキストのセンチメントアナリシス（ネガ-ポジスコア）
# 「時は内乱の最中である。秘密基地を発った反乱軍の宇宙船団が、邪悪な銀河帝国軍に対して初の勝利を収めた。この戦いで、反乱軍のスパイは帝国軍の究極兵器の設計図を奪取することに成功する。それはデス・スターと呼ばれる、惑星をも完全に破壊できる力を持った巨大宇宙ステーションだった。設計図を受け取ったレイア姫は、人々を救い、銀河系に平和を取り戻すべく、自船で故郷へと向かうが
# 帝国軍の密使に発見されてしまったのだった・・・」
# ⬇︎

# %% [markdown]
# {'時': -0.753339, '内乱': -0.424156, '最中': -0.518285, '邪悪': -0.998351, '初': -0.470901, '勝利': 0.640964, '収める': -0.855641, '戦い': -0.767698, 'スパイ': -0.355393, '成功': -0.387167, '呼ぶ': -0.931867, '惑星': -0.463749, '完全': -0.317574, '破壊': -0.454169, '力': -0.84291, '救う': 0.989773, '銀河系': -0.199152, '平和': 0.170938, '故郷': -0.508876, '向かう': -0.74591, '密使': -0.259138, '発見': -0.309154}

# %% [markdown]
# 少し見辛いが、上記に示すように、単語ごとにスコアリングを行い（東北大学の研究室で公開されている辞書を用いている）、文章がネガティブなのかポジティブなのかの判定を行った。
# 単語のスコアを頻出量などで補正して、足し合わせるなどをして文章のスコアを算出した。
# このような分析を行うことで、顧客とのやり取りの文章について解約にいたってしまったタイミングを事前に検知できないかなどの分析を行った。

# %% [markdown]
# # 報告書テキストのクラスタリング
# ![あ.png](attachment:%E3%82%AF%E3%83%A9%E3%82%B9%E3%82%BF%E3%83%AA%E3%83%B3%E3%82%AF%E3%82%99.png)

# %% [markdown]
# こちらは、あるテキストデータを無教師機械学習でクラスタリングを行った結果である。
# クラスタリングは、似たデータがまとまった群を形成し現れるようにする手法である。
# (厳密には上記のグラフのように、人にわかりやすく視覚化する部分は別の手法になります。)
# ここでは解約してしまった顧客のテキストデータは何かしらのクラスタを形成しているのではないかなどの分析行った。
