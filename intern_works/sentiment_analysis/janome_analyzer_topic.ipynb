# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from janome.tokenizer import Tokenizer
t = Tokenizer()

# %%
text = "庭には二羽鶏がいます"
text2 = "坊主が屏風に上手にジョーズを描いた"
text3 = "すもももももももものうち"

# %%
tokens = t.tokenize(text)
for token in tokens:
    print(token)
# Out:
# 庭	名詞,一般,*,*,*,*,庭,ニワ,ニワ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 二	名詞,数,*,*,*,*,二,ニ,ニ
# 羽	名詞,接尾,助数詞,*,*,*,羽,ワ,ワ
# 鶏	名詞,一般,*,*,*,*,鶏,ニワトリ,ニワトリ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# い	動詞,自立,*,*,一段,連用形,いる,イ,イ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス

# %%
tokens = t.tokenize(text2)
for token in tokens:
    print(token)
# Out:
# 坊主	名詞,一般,*,*,*,*,坊主,ボウズ,ボーズ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 屏風	名詞,一般,*,*,*,*,屏風,ビョウブ,ビョーブ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 上手	名詞,形容動詞語幹,*,*,*,*,上手,ジョウズ,ジョーズ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# ジョーズ	名詞,一般,*,*,*,*,ジョーズ,*,*
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 描い	動詞,自立,*,*,五段・カ行イ音便,連用タ接続,描く,エガイ,エガイ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ

# %%
tokens = t.tokenize(text3)
print(type(tokens))
for token in tokens:
    print(token)
# Out:
# <class 'list'>
# すもも	名詞,一般,*,*,*,*,すもも,スモモ,スモモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# うち	名詞,非自立,副詞可能,*,*,*,うち,ウチ,ウチ

# %%
print(type(tokens[0]))
print(tokens[0].surface)
# Out:
# <class 'janome.tokenizer.Token'>
# すもも

# %%
print([token.surface for token in tokens])
# Out:
# ['すもも', 'も', 'もも', 'も', 'もも', 'の', 'うち']

# %%
print([token.base_form for token in t.tokenize(text)])
# Out:
# ['庭', 'に', 'は', '二', '羽', '鶏', 'が', 'いる', 'ます']

# %%
print([token.part_of_speech for token in t.tokenize(text)])
# Out:
# ['名詞,一般,*,*', '助詞,格助詞,一般,*', '助詞,係助詞,*,*', '名詞,数,*,*', '名詞,接尾,助数詞,*', '名詞,一般,*,*', '助詞,格助詞,一般,*', '動詞,自立,*,*', '助動詞,*,*,*']

# %%
text4 = 'gps誤差が大きいですか、改善はできますか？\n\n本製品には大いに期待しているのですが、GPSの誤差がひどすぎるので改善の余地は御座いますでしょうか。  もしあれば何時までに、またないようであればそれもお教えください。  より一層の発展お祈り差し上げます。GPSの誤差に関しては、環境や設定によって改善致します。スマートフォン設定についてまず確認をお願いします。\n\nアンドロイド端末の場合\nhttps://cyzen.zendesk.com/hc/ja/articles/221641588\n\nｉＰｈｏｎｅの場合\nhttps://cyzen.zendesk.com/hc/ja/articles/221709547\n\nお客様のデータを拝見いたしますと、iPhoneの誤差が多いように見えます。\niPhoneを利用している方はGPSを取得しづらい場所にいることが多いなどの傾向はありますでしょうか？\nGPS が取得しずらい場合は、基地局やＷＩＦＩを利用して位置情報を取得します。\n念のためWiFiが有効かどうかもご確認いただけますでしょうか？。。'

# %%
tokens = t.tokenize(text4)
for token in tokens:
    print(token)
# Out:
# gps	名詞,固有名詞,組織,*,*,*,gps,*,*
# 誤差	名詞,一般,*,*,*,*,誤差,ゴサ,ゴサ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 大きい	形容詞,自立,*,*,形容詞・イ段,基本形,大きい,オオキイ,オーキイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 、	記号,読点,*,*,*,*,、,、,、
# 改善	名詞,サ変接続,*,*,*,*,改善,カイゼン,カイゼン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ？	記号,一般,*,*,*,*,？,？,？
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 本	接頭詞,名詞接続,*,*,*,*,本,ホン,ホン
# 製品	名詞,一般,*,*,*,*,製品,セイヒン,セイヒン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 大いに	副詞,一般,*,*,*,*,大いに,オオイニ,オーイニ
# 期待	名詞,サ変接続,*,*,*,*,期待,キタイ,キタイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# GPS	名詞,固有名詞,組織,*,*,*,GPS,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 誤差	名詞,一般,*,*,*,*,誤差,ゴサ,ゴサ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# ひど	形容詞,自立,*,*,形容詞・アウオ段,ガル接続,ひどい,ヒド,ヒド
# すぎる	動詞,非自立,*,*,一段,基本形,すぎる,スギル,スギル
# ...

# %%
from janome.analyzer import Analyzer
from janome.tokenfilter import *
from janome.charfilter import *

# %%
class NumericReplaceFilter(TokenFilter):
    """
    名詞中の数(漢数字を含む)を全て0に置き換えるTokenFilterの実装
    """
    def apply(self, tokens):
        for token in tokens:
            parts = token.part_of_speech.split(',')
            if (parts[0] == '名詞' and parts[1] == '数'):
                token.surface = '0'
                token.base_form = '0'
                token.reading = 'ゼロ'
                token.phonetic = 'ゼロ'
            yield token

# %%
char_filters = [RegexReplaceCharFilter('<.*?>', ''),
                RegexReplaceCharFilter(r'https*?', ''),
                UnicodeNormalizeCharFilter()] 
token_filters = [#NumericReplaceFilter(), # 名詞中の漢数字を含む数字を0に置換
                 #CompoundNounFilter(), # 名詞が連続する場合は複合名詞にする
                 POSKeepFilter(['名詞', '動詞', '形容詞', '副詞']), # 名詞・動詞・形容詞・副詞のみを取得する
                 LowerCaseFilter()] # 英字は小文字にする
analyzer = Analyzer(char_filters, t, token_filters)

# %%
for token in analyzer.analyze(text4):
    print(token)
# Out:
# gps	名詞,固有名詞,組織,*,*,*,gps,*,*
# 誤差	名詞,一般,*,*,*,*,誤差,ゴサ,ゴサ
# 大きい	形容詞,自立,*,*,形容詞・イ段,基本形,大きい,オオキイ,オーキイ
# 改善	名詞,サ変接続,*,*,*,*,改善,カイゼン,カイゼン
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ?	名詞,サ変接続,*,*,*,*,?,*,*
# 製品	名詞,一般,*,*,*,*,製品,セイヒン,セイヒン
# 大いに	副詞,一般,*,*,*,*,大いに,オオイニ,オーイニ
# 期待	名詞,サ変接続,*,*,*,*,期待,キタイ,キタイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# gps	名詞,固有名詞,組織,*,*,*,gps,*,*
# 誤差	名詞,一般,*,*,*,*,誤差,ゴサ,ゴサ
# ひど	形容詞,自立,*,*,形容詞・アウオ段,ガル接続,ひどい,ヒド,ヒド
# すぎる	動詞,非自立,*,*,一段,基本形,すぎる,スギル,スギル
# 改善	名詞,サ変接続,*,*,*,*,改善,カイゼン,カイゼン
# 余地	名詞,一般,*,*,*,*,余地,ヨチ,ヨチ
# 御座い	動詞,自立,*,*,五段・ラ行特殊,連用形,御座る,ゴザイ,ゴザイ
# もし	副詞,一般,*,*,*,*,もし,モシ,モシ
# あれ	動詞,自立,*,*,五段・ラ行,仮定形,ある,アレ,アレ
# 何	名詞,数,*,*,*,*,何,ナン,ナン
# 時	名詞,接尾,助数詞,*,*,*,時,ジ,ジ
# また	副詞,助詞類接続,*,*,*,*,また,マタ,マタ
# ない	形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# それ	名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# 教え	動詞,自立,*,*,一段,連用形,教える,オシエ,オシエ
# ください	動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,くださる,クダサイ,クダサイ
# より	副詞,一般,*,*,*,*,より,ヨリ,ヨリ
# ...

# %%
text5 = '<div class="cyzen">CyzenとＣＹＺＥＮと\n'\
         'サイゼンとｻｲｾﾞﾝ。</div>'

# %%
for token in analyzer.analyze(text5):
    print(token)
# Out:
# cyzen	名詞,固有名詞,組織,*,*,*,cyzen,*,*
# cyzen	名詞,固有名詞,組織,*,*,*,cyzen,*,*
# サイゼン	名詞,一般,*,*,*,*,サイゼン,*,*
# サイゼン	名詞,一般,*,*,*,*,サイゼン,*,*

# %%
text6 = 'わたしたちは、世界中の働く人に新しいワークスタイルを提案し続けます。\n世界中の働く人が『働くを、もっと楽しく』感じる世界を実現します。\nそれらを通じて、あらゆるステークホルダーが\n『働くを、もっと楽しく』感じるようになります。\nそんな企業になることが、『働くを、もっと楽しく』、に込められています。'

# %%
text6 = '<p class="text on" style="opacity: 1; display: block; transform: translateY(0px);">\t\t\t\t\t\tわたしたちは、世界中の働く人に新しいワークスタイルを提案し続けます。<br>世界中の働く人が『働くを、もっと楽しく』感じる世界を実現します。<br>それらを通じて、あらゆるステークホルダーが<br>『働くを、もっと楽しく』感じるようになります。<br>そんな企業になることが、『働くを、もっと楽しく』、に込められています。\t\t\t\t</p>'

# %%
char_filters2 = [RegexReplaceCharFilter('<.*?>', ''),
                #RegexReplaceCharFilter(r'、'),
                UnicodeNormalizeCharFilter()] 
token_filters2 = [#NumericReplaceFilter(), # 名詞中の漢数字を含む数字を0に置換
                 CompoundNounFilter(), # 名詞が連続する場合は複合名詞にする
                 POSKeepFilter(['名詞']), # 名詞・動詞・形容詞・副詞のみを取得する
                 LowerCaseFilter()] # 英字は小文字にする
analyzer = Analyzer(char_filters2, t, token_filters2)

# %%
text6
# Out:
# '<p class="text on" style="opacity: 1; display: block; transform: translateY(0px);">\t\t\t\t\t\tわたしたちは、世界中の働く人に新しいワークスタイルを提案し続けます。<br>世界中の働く人が『働くを、もっと楽しく』感じる世界を実現します。<br>それらを通じて、あらゆるステークホルダーが<br>『働くを、もっと楽しく』感じるようになります。<br>そんな企業になることが、『働くを、もっと楽しく』、に込められています。\t\t\t\t</p>'

# %%
for token in analyzer.analyze(text6):
    print(token)
# Out:
# わたしたち	名詞,複合,*,*,*,*,わたしたち,ワタシタチ,ワタシタチ
# 世界中	名詞,一般,*,*,*,*,世界中,セカイジュウ,セカイジュー
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# ワークスタイル	名詞,複合,*,*,*,*,ワークスタイル,ワークスタイル,ワークスタイル
# 提案	名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン
# 世界中	名詞,一般,*,*,*,*,世界中,セカイジュウ,セカイジュー
# 人	名詞,一般,*,*,*,*,人,ヒト,ヒト
# 世界	名詞,一般,*,*,*,*,世界,セカイ,セカイ
# 実現	名詞,サ変接続,*,*,*,*,実現,ジツゲン,ジツゲン
# それら	名詞,代名詞,一般,*,*,*,それら,ソレラ,ソレラ
# ステークホルダー	名詞,複合,*,*,*,*,ステークホルダー,ステークホルダー,ステークホルダー
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# 企業	名詞,一般,*,*,*,*,企業,キギョウ,キギョー
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
